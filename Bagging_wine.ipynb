# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('wine.csv')
data
# Out:
#      wine  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0       1    14.23        1.71  2.43               15.6        127
# 1       1    13.20        1.78  2.14               11.2        100
# 2       1    13.16        2.36  2.67               18.6        101
# 3       1    14.37        1.95  2.50               16.8        113
# 4       1    13.24        2.59  2.87               21.0        118
# ..    ...      ...         ...   ...                ...        ...
# 173     3    13.71        5.65  2.45               20.5         95
# 174     3    13.40        3.91  2.48               23.0        102
# 175     3    13.27        4.28  2.26               20.0        120
# 176     3    13.17        2.59  2.37               20.0        120
# 177     3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   wine                          178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
# ...

# %%
data.describe()
# Out:
#              wine     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
data.head()
# Out:
#    wine  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0     1    14.23        1.71  2.43               15.6        127
# 1     1    13.20        1.78  2.14               11.2        100
# 2     1    13.16        2.36  2.67               18.6        101
# 3     1    14.37        1.95  2.50               16.8        113
# 4     1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %%
data.tail()
# Out:
#      wine  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 173     3    13.71        5.65  2.45               20.5         95
# 174     3    13.40        3.91  2.48               23.0        102
# 175     3    13.27        4.28  2.26               20.0        120
# 176     3    13.17        2.59  2.37               20.0        120
# 177     3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 173              7.7  0.64                          1.74      740
# ...

# %%
data.columns
# Out:
# Index(['wine', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %%
data.wine.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
data.wine.value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: wine, dtype: int64

# %% [markdown]
# #### Renaming column names

# %%
data.rename(columns={'Alcohol':'alcohol', 'Malic acid':'m_acid', 'Ash':'ash','Alcalinity of ash':'AOA', 'Total phenols':'total_phe', 'Nonflavanoid phenols':'NOP',
       'Proanthocyanins':'pro_cyanin', 'Color intensity':'color_intensity','Hue':'hue',
       'OD280/OD315 of diluted wines':'DW'},inplace=True)

# %%
data
# Out:
#      wine  alcohol  m_acid   ash   AOA  Magnesium  total_phe  Flavanoids  \
# 0       1    14.23    1.71  2.43  15.6        127       2.80        3.06
# 1       1    13.20    1.78  2.14  11.2        100       2.65        2.76
# 2       1    13.16    2.36  2.67  18.6        101       2.80        3.24
# 3       1    14.37    1.95  2.50  16.8        113       3.85        3.49
# 4       1    13.24    2.59  2.87  21.0        118       2.80        2.69
# ..    ...      ...     ...   ...   ...        ...        ...         ...
# 173     3    13.71    5.65  2.45  20.5         95       1.68        0.61
# 174     3    13.40    3.91  2.48  23.0        102       1.80        0.75
# 175     3    13.27    4.28  2.26  20.0        120       1.59        0.69
# 176     3    13.17    2.59  2.37  20.0        120       1.65        0.68
# 177     3    14.13    4.10  2.74  24.5         96       2.05        0.76
#
#       NOP  pro_cyanin  color_intensity   hue    DW  Proline
# ...

# %%
plt.figure(figsize=(20,20),facecolor='white')
plotnumber=1

for column in data.drop('wine',axis=1):
        if plotnumber<=12:
            ax=plt.subplot(4,3,plotnumber)
            sns.distplot(x=data[column])
            plt.xlabel(column)
        plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Data preprocessing

# %%
data.isnull().sum()
# Out:
# wine               0
# alcohol            0
# m_acid             0
# ash                0
# AOA                0
# Magnesium          0
# total_phe          0
# Flavanoids         0
# NOP                0
# pro_cyanin         0
# color_intensity    0
# hue                0
# DW                 0
# Proline            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Outliers handling

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)

IQR = Q3-Q1

min_limit = Q1-1.5*IQR
max_limit = Q3+1.5*IQR

outliers_count = ((data > max_limit) | (data < min_limit)).sum()

outliers_percentage = (outliers_count/len(data))*100

print('\n Sum of Outliers:\n',outliers_count)
print('\n Percentage of Outliers:\n',outliers_percentage)
# Out:
#  Sum of Outliers:
#  wine               0
# alcohol            0
# m_acid             3
# ash                3
# AOA                4
# Magnesium          4
# total_phe          0
# Flavanoids         0
# NOP                0
# pro_cyanin         2
# color_intensity    4
# hue                1
# DW                 0
# Proline            0
# dtype: int64
#
#  Percentage of Outliers:
#  wine               0.000000
# alcohol            0.000000
# m_acid             1.685393
# ash                1.685393
# AOA                2.247191
# Magnesium          2.247191
# total_phe          0.000000
# Flavanoids         0.000000
# NOP                0.000000
# pro_cyanin         1.123596
# color_intensity    2.247191
# hue                0.561798
# DW                 0.000000
# Proline            0.000000
# dtype: float64

# %%
plt.figure(figsize=(20,20),facecolor='white')
plotnumber=1

for column in data.drop('wine',axis=1):
        if plotnumber<9:
            ax=plt.subplot(4,2,plotnumber)
            sns.boxplot(x=data[column])
            plt.xlabel(column)
        plotnumber+=1
plt.tight_layout()

# %%
## m_acid

from scipy import stats

Q1 = np.percentile(data.m_acid,25)
Q3 = np.percentile(data.m_acid,75)

IQR = stats.iqr(data['m_acid'])

max_limit = Q3+(1.5*IQR)
min_limit = Q1-(1.5*IQR)

data.loc[(data['m_acid'] > max_limit) | (data['m_acid'] < min_limit),'m_acid'] = np.median(data['m_acid'])

# %%
## ash

Q1 = data.ash.quantile(0.25)
Q3 = data.ash.quantile(0.75)
IQR = stats.iqr(data['ash'])

max_limit = Q3+(1.5*IQR)
min_limit = Q1-(1.5*IQR)

data.loc[(data['ash'] > max_limit) | (data['ash'] < min_limit),'ash'] = np.mean(data['ash'])

# %%
## AOA

mean = np.mean(data['AOA'])

std = np.std(data['AOA'])

min_value = mean-(3*std)
max_value = mean+(3*std)

data.loc[(data['AOA'] > max_value) | (data['AOA'] < min_value),'AOA'] = np.mean(data['AOA'])

# %%
## Magnesium

Q1 = data.Magnesium.quantile(0.25)
Q3 = data.Magnesium.quantile(0.75)
IQR = stats.iqr(data['Magnesium'])

max_limit = Q3+(1.5*IQR)
min_limit = Q1-(1.5*IQR)

data.loc[(data['Magnesium'] > max_limit) | (data['Magnesium'] < min_limit),'Magnesium'] = np.median(data['Magnesium'])

# %%
## pro_cyanin

Q1 = data.pro_cyanin.quantile(0.25)
Q3 = data.pro_cyanin.quantile(0.75)
IQR = stats.iqr(data['pro_cyanin'])

max_limit = Q3+(1.5*IQR)
min_limit = Q1-(1.5*IQR)

data.loc[(data['pro_cyanin'] > max_limit) | (data['pro_cyanin'] < min_limit),'pro_cyanin'] = np.median(data['pro_cyanin'])

# %%
## color_intensity

Q1 = data.color_intensity.quantile(0.25)
Q3 = data.color_intensity.quantile(0.75)
IQR = stats.iqr(data['color_intensity'])

max_limit = Q3+(1.5*IQR)
min_limit = Q1-(1.5*IQR)

data.loc[(data['color_intensity'] > max_limit) | (data['color_intensity'] < min_limit),'color_intensity'] = np.median(data['color_intensity'])

# %%
## hue

Q1 = data.hue.quantile(0.25)
Q3 = data.hue.quantile(0.75)
IQR = stats.iqr(data['hue'])

max_limit = Q3+(1.5*IQR)
min_limit = Q1-(1.5*IQR)

data.loc[(data['hue'] > max_limit) | (data['hue'] < min_limit),'hue'] = np.median(data['hue'])

# %%
'''data3 = ['m_acid','AOA','ash','Magnesium','pro_cyanin','color_intensity','hue']
for column in data3:
    Q1 = np.percentile(data[column],25)
    Q3 = np.percentile(data[column],75)

    IQR = stats.iqr(data[column])

    max_limit = Q3+(1.5*IQR)
    min_limit = Q1-(1.5*IQR)

    data.loc[(data[column] > max_limit) | (data[column] < min_limit),column] = np.median(data[column])'''
# Out:
# "data3 = ['m_acid','AOA','ash','Magnesium','pro_cyanin','color_intensity','hue']\nfor column in data3:\n    Q1 = np.percentile(data[column],25)\n    Q3 = np.percentile(data[column],75)\n\n    IQR = stats.iqr(data[column])\n\n    max_limit = Q3+(1.5*IQR)\n    min_limit = Q1-(1.5*IQR)\n\n    data.loc[(data[column] > max_limit) | (data[column] < min_limit),column] = np.median(data[column])"

# %%
plt.figure(figsize=(20,20),facecolor='white')
plotnumber=1

for column in data.drop('wine',axis=1):
        if plotnumber<=12:
            ax=plt.subplot(4,3,plotnumber)
            sns.boxplot(x=data[column])
            plt.xlabel(column)
        plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### scaling

# %%
# splitting the data

x = data.drop('wine',axis=1)
y = data.wine

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42)

# %%
## model implementation

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

model = SVC(kernel='linear')

model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9777777777777777

# %% [markdown]
# ## Bagging

# %%
from sklearn.ensemble import BaggingClassifier

model_bag = BaggingClassifier(base_estimator=model,n_estimators=20)

model_bag.fit(x_train,y_train)
# Out:
# BaggingClassifier(base_estimator=KNeighborsClassifier(), n_estimators=20)

# %%
y_pred_bag = model.predict(x_test)

# %%
accuracy_score(y_test,y_pred_bag)
# Out:
# 0.6888888888888889
